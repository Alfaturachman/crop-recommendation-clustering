# %% [markdown]
# # Proyek Tugas Akhir: Klasterisasi Lahan Pertanian Berdasarkan Karakteristik Agronomi untuk Sistem Rekomendasi Tanaman Multilabel
#
# ## 1. Ringkasan Akademik & Formulasi Masalah
#
# ### 1.1 Latar Belakang (Context)
# Dalam era pertanian presisi (*precision agriculture*), optimalisasi pemilihan komoditas berdasarkan kecocokan agro-klimatologi lahan sangat penting untuk meningkatkan produktivitas dan menjaga keberlanjutan tanah. Kondisi agronomi lahan ditentukan oleh parameter biofisik tanah (makronutrien Nitrogen [N], Fosfor [P], Kalium [K], dan tingkat keasaman [pH]) serta kondisi mikroklimat (suhu, kelembaban udara, dan curah hujan).
#
# Pada umumnya, permasalahan rekomendasi tanaman didekati dengan metode pembelajaran terawasi klasifikasi multi-kelas (*supervised multi-class classification*) di mana model memetakan parameter tanah ke satu jenis tanaman ($X \to Y$). Namun, secara ekologis dan bisnis pertanian, pendekatan ini terlalu membatasi (*rigid*). Satu karakteristik lahan tertentu sering kali adaptif terhadap lebih dari satu komoditas tanaman. Oleh karena itu, rekomendasi tanaman yang realistis harus dirancang sebagai sistem rekomendasi multilabel (*multilabel crop recommendation*) untuk memfasilitasi petani dalam rotasi tanaman (*crop rotation*), tumpang sari (*intercropping*), dan diversifikasi risiko pertanian.
#
# ### 1.2 Formulasi Permasalahan (Problem Formulation)
# Kritik utama terhadap pendekatan supervised konvensional yang melandasi urgensi penelitian ini meliputi:
# 1. **Keterbatasan Output Tunggal (*Single-Label Output Constraint*)**: Model klasifikasi supervised konvensional memprediksi satu tanaman terbaik saja per input lahan. Hal ini meniadakan peluang alternatif komoditas lain yang memiliki toleransi tumbuh serupa di lahan tersebut.
# 2. **Ketiadaan Dataset Multilabel Aktual (*Lack of Multilabel Labeled Dataset*)**: Dataset publik yang umum digunakan (seperti *Crop Recommendation Dataset*) hanya menyediakan satu label tanaman per baris data. Melakukan pencatatan multilabel secara manual di lapangan membutuhkan biaya tinggi dan waktu yang lama.
# 3. **Rigiditas Batas Wilayah Lahan (*Rigidity of Land Boundary Decisions*)**: Karakteristik tanah bersifat kontinu. Penggunaan klasterisasi keras (*hard clustering*) seperti K-Means atau K-Medoids menghasilkan pemisahan spasial yang kaku, sehingga kurang mampu menangani area perbatasan klaster (zona transisi). Hal ini memicu perlunya eksplorasi algoritma klasterisasi berbasis kerapatan (*DBSCAN*) dan alternatif berbasis probabilitas/fuzzy.
#
# ### 1.3 Solusi Unsupervised & Novelty (Proposed Solution & Value Proposition)
# Untuk memecahkan permasalahan di atas, penelitian ini memformulasikan kembali tugas rekomendasi tanaman menjadi masalah **Klasterisasi Unsupervised berbasis Reduksi Dimensi PCA**:
# - **Pemetaan Multilabel Alami via Klasterisasi**: Dengan mengelompokkan data lahan tanpa pengawasan label (*unsupervised*), kita mengelompokkan profil tanah yang serupa. Setiap klaster akan menampung beberapa jenis tanaman yang tumbuh subur pada rentang parameter yang berdekatan. Dengan demikian, ketika ada data lahan baru, kita cukup mengidentifikasi klasternya dan menyajikan seluruh varietas tanaman unik di klaster tersebut sebagai rekomendasi multilabel alternatif.
# - **Komparasi Geometris dan Kerapatan**: Kami membandingkan algoritma berbasis pusat (*centroid-based*) yaitu **K-Means** dengan algoritma berbasis kerapatan (*density-based*) yaitu **DBSCAN** pada ruang reduksi dimensi PCA 5D untuk menganalisis karakteristik spasial data agronomi.
# - **Kebijakan Pemeliharaan Outlier**: Kami mempertahankan outlier statistik terdeteksi karena dalam domain pertanian, pencilan data agronomi mencerminkan kebutuhan biologis ekstrim yang sah dari komoditas bernilai tinggi (misalnya: apel/anggur membutuhkan kalium sangat tinggi, padi membutuhkan curah hujan sangat tinggi). Penghapusan outlier akan melenyapkan varietas tanaman ini dari taksonomi model.
#
# **Alur Analisis:**
# 1. Import Library
# 2. Data Loading
# 3. Data Understanding
# 4. Data Cleaning & Outlier Analysis
# 5. Exploratory Data Analysis (EDA)
# 6. Data Preprocessing (Scaling)
# 7. Feature Engineering (Principal Component Analysis - PCA)
# 8. Training Model (K-Means & DBSCAN)
# 9. Evaluasi Model (Silhouette Score, Davies-Bouldin Index, Adjusted Rand Index)
# 10. Visualisasi Hasil Klasterisasi (2D & 5D)
# 11. Analisis & Interpretasi Karakteristik Centroid Klaster
# 12. Kesimpulan dan Saran

# %% [markdown]
# ## 1. Import Library
# Memuat semua pustaka yang dibutuhkan untuk manipulasi data, visualisasi, dan pemodelan machine learning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing & Machine Learning
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import silhouette_score, davies_bouldin_score, adjusted_rand_score

# Pengaturan visualisasi & peringatan
import warnings
warnings.filterwarnings('ignore')
sns.set(style='whitegrid', palette='muted')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## 2. Data Loading
# Memuat dataset `crop_recommendation.csv` ke dalam Pandas DataFrame.

# %%
# Load dataset
df = pd.read_csv('crop_recommendation.csv')

# Menampilkan 5 baris pertama dataset
display(df.head())
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %% [markdown]
# ## 3. Data Understanding
# Menganalisis struktur data, tipe data, dan statistik deskriptif awal.

# %%
# Informasi umum dataset
print("Informasi Dataset:")
df.info()

print("\nStatistik Deskriptif:")
display(df.describe())

print("\nDistribusi Label (Jenis Tanaman):")
display(df['label'].value_counts())
# Out:
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB
#
# Statistik Deskriptif:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117
# Distribusi Label (Jenis Tanaman):
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %% [markdown]
# ### Visualisasi Distribusi Target Label (Tanaman)
# Grafik batang di bawah ini menunjukkan penyebaran jumlah data sampel untuk masing-masing kelas tanaman dalam dataset.

# %%
# Visualisasi Distribusi Jumlah Data per Jenis Tanaman
plt.figure(figsize=(12, 6))
sns.countplot(y='label', data=df, order=df['label'].value_counts().index, palette='viridis')
plt.title('Distribusi Jumlah Sampel per Jenis Tanaman (Label)')
plt.xlabel('Jumlah Sampel')
plt.ylabel('Jenis Tanaman')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Data Cleaning
# Memeriksa adanya *missing values* (nilai yang hilang) dan data duplikat.

# %%
# Cek Missing Values
print("Jumlah Missing Values per Kolom:")
print(df.isnull().sum())

# Cek Duplikasi
duplicates = df.duplicated().sum()
print(f"\nJumlah data duplikat: {duplicates}")

# Menghapus duplikat jika ada
if duplicates > 0:
    df = df.drop_duplicates()
    print("Data duplikat telah dihapus.")
else:
    print("Tidak ada data duplikat.")
# Out:
# Jumlah Missing Values per Kolom:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64
#
# Jumlah data duplikat: 0
# Tidak ada data duplikat.

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
# Melakukan analisis univariat dan bivariat untuk memahami distribusi dan hubungan antar fitur.

# %%
# Distribusi fitur numerik (Univariat)
numeric_cols = df.select_dtypes(include=[np.number]).columns

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 12))
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    sns.histplot(df[col], kde=True, ax=axes[i], color='skyblue')
    axes[i].set_title(f'Distribusi {col}')
    axes[i].set_xlabel('')
    
# Hapus axis yang kosong
for j in range(len(numeric_cols), len(axes)):
    fig.delaxes(axes[j])
    
plt.tight_layout()
plt.show()

# %%
# Deteksi Outlier menggunakan Boxplot
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 12))
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    sns.boxplot(y=df[col], ax=axes[i], color='lightgreen')
    axes[i].set_title(f'Boxplot {col}')
    
# Hapus axis yang kosong
for j in range(len(numeric_cols), len(axes)):
    fig.delaxes(axes[j])
    
plt.tight_layout()
plt.show()

# %%
# Korelasi antar fitur (Multivariat)
plt.figure(figsize=(10, 8))
corr_matrix = df[numeric_cols].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Matriks Korelasi Fitur Agronomi")
plt.show()

# %% [markdown]
# ## 6. Data Preprocessing
# Pemisahan fitur dan label, serta standarisasi fitur (Scaling) agar algoritma jarak seperti K-Means dan DBSCAN bekerja optimal.

# %%
# Memisahkan fitur dan label
X = df.drop('label', axis=1)
y_true = df['label'] # Disimpan untuk evaluasi Adjusted Rand Index (ARI)

# Scaling menggunakan StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print(f"Dimensi data setelah scaling: {X_scaled.shape}")
# Out:
# Dimensi data setelah scaling: (2200, 7)

# %%
# Melihat jumlah total kelompok unik (berupa angka)
print(f"Jumlah label unik: {y_true.nunique()}")

# Melihat nama-nama kelompok atau kategori unik tersebut
print(f"Daftar label asli: {y_true.unique()}")

# %% [markdown]
# ## 7. Feature Engineering (PCA)
# Principal Component Analysis (PCA) digunakan untuk mereduksi dimensi data.
# Untuk pemodelan (*modeling*), kita akan menggunakan `PCA(n_components=5)` agar dapat mempertahankan informasi yang tinggi (~89% variansi kumulatif) dan menghasilkan nilai ARI (*Adjusted Rand Index*) yang lebih optimal.
# Sedangkan untuk visualisasi, kita akan memproyeksikan data ke `PCA(n_components=2)` agar dapat diplot dalam grafik 2D.
# Kita juga akan menyertakan visualisasi 5 komponen utama menggunakan pairplot untuk mengamati persebaran data dalam dimensi yang lebih tinggi secara keseluruhan.

# %%
# Coba langsung cari sampai 5 komponen
pca_test = PCA(n_components=5)
pca_test.fit(X_scaled)

import numpy as np
cumulative_variance = np.cumsum(pca_test.explained_variance_ratio_)

for i, total_info in enumerate(cumulative_variance):
    print(f"Jika pakai {i+1} komponen, informasi yang terjaga: {total_info * 100:.2f}%")
# Out:
# Jika pakai 1 komponen, informasi yang terjaga: 27.59%
# Jika pakai 2 komponen, informasi yang terjaga: 46.07%
# Jika pakai 3 komponen, informasi yang terjaga: 61.45%
# Jika pakai 4 komponen, informasi yang terjaga: 76.06%
# Jika pakai 5 komponen, informasi yang terjaga: 87.58%

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# 1. Clustering menggunakan 2 Komponen (Data Lama)
pca_2 = PCA(n_components=2)
X_pca_2 = pca_2.fit_transform(X_scaled)
kmeans_2 = KMeans(n_clusters=len(y_true.unique()), random_state=42)
labels_2 = kmeans_2.fit_predict(X_pca_2)
ari_2 = adjusted_rand_score(y_true, labels_2)

# 2. Clustering menggunakan 5 Komponen (Rekomendasi Best Practice)
pca_5 = PCA(n_components=5)
X_pca_5 = pca_5.fit_transform(X_scaled)
kmeans_5 = KMeans(n_clusters=len(y_true.unique()), random_state=42)
labels_5 = kmeans_5.fit_predict(X_pca_5)
ari_5 = adjusted_rand_score(y_true, labels_5)

print(f"Nilai ARI dengan 2 Komponen: {ari_2:.4f}")
print(f"Nilai ARI dengan 5 Komponen: {ari_5:.4f}")
# Out:
# Nilai ARI dengan 2 Komponen: 0.3032
# Nilai ARI dengan 5 Komponen: 0.5624

# %%
# PCA dengan 5 komponen untuk pemodelan (modeling)
pca_5 = PCA(n_components=5)
X_pca_5 = pca_5.fit_transform(X_scaled)

# PCA dengan 2 komponen untuk visualisasi 2D
pca_2 = PCA(n_components=2)
X_pca_2 = pca_2.fit_transform(X_scaled)

# Menyimpan hasil PCA 2D ke dalam dataframe untuk visualisasi
pca_df = pd.DataFrame(data=X_pca_2, columns=['PC1', 'PC2'])
pca_df['label'] = y_true

# 1. Visualisasi 2D (PCA 2 komponen) berdasarkan Label Asli
plt.figure(figsize=(10, 7))
sns.scatterplot(x='PC1', y='PC2', hue='label', data=pca_df, palette='tab20', legend=False, alpha=0.7)
plt.title("Visualisasi 2D Data Tanaman (PCA 2 Komponen) berdasarkan Label Asli")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()

# 2. Visualisasi 5D (PCA 5 komponen) berdasarkan Label Asli (menggunakan Pairplot)
pca_5_df = pd.DataFrame(data=X_pca_5, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])
pca_5_df['label'] = y_true

# Pairplot 5 komponen PCA
sns.pairplot(pca_5_df, hue='label', palette='tab20', plot_kws={'alpha': 0.5}, corner=True)
plt.suptitle("Visualisasi Pairplot 5 Komponen PCA berdasarkan Label Asli", y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# ## 8. Training Model: K-Means Clustering
# Mencari jumlah klaster optimal (*K*) menggunakan **Elbow Method** dan **Silhouette Score**, dilanjutkan dengan pelatihan model.

# %%
# Menentukan K optimal dengan Elbow Method & Silhouette Score menggunakan data PCA (5 komponen)
wcss = []
silhouette_scores = []
K_range = range(2, 30)

for k in K_range:
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42, n_init=10)
    kmeans.fit(X_pca_5)
    wcss.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(X_pca_5, kmeans.labels_))

# Visualisasi Elbow Method
fig, ax1 = plt.subplots(figsize=(12, 6))

color = 'tab:blue'
ax1.set_xlabel('Number of Clusters (K)')
ax1.set_ylabel('WCSS', color=color)
ax1.plot(K_range, wcss, marker='o', color=color, label='WCSS')
ax1.tick_params(axis='y', labelcolor=color)

# Visualisasi Silhouette Score
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('Silhouette Score', color=color)
ax2.plot(K_range, silhouette_scores, marker='s', color=color, label='Silhouette Score')
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.title('Elbow Method dan Silhouette Score untuk K-Means (pada 5 Komponen PCA)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# Berdasarkan dataset asli, kita memiliki 22 jenis tanaman. Mari kita gunakan $K=22$ untuk pelatihan model K-Means, yang juga merupakan area yang masuk akal pada kurva Silhouette.

# %%
# Melatih K-Means dengan K=22 pada data PCA (5 komponen)
k_optimal = 22
kmeans_model = KMeans(n_clusters=k_optimal, init='k-means++', random_state=42, n_init=10)
kmeans_labels = kmeans_model.fit_predict(X_pca_5)

# Menyimpan hasil prediksi K-Means ke dataframe PCA (untuk visualisasi 2D)
pca_df['KMeans_Cluster'] = kmeans_labels

# %% [markdown]
# ## 9. Training Model: DBSCAN
# Menentukan nilai *Epsilon* (eps) optimal menggunakan K-Distance Graph, lalu melatih model DBSCAN.

# %%
# K-Distance Graph untuk menentukan Epsilon menggunakan data PCA (5 komponen)
min_samples = 10 # 2 * D (dimensi data PCA = 5)
neighbors = NearestNeighbors(n_neighbors=min_samples)
neighbors_fit = neighbors.fit(X_pca_5)
distances, indices = neighbors_fit.kneighbors(X_pca_5)

distances = np.sort(distances[:, -1], axis=0)

plt.figure(figsize=(10, 6))
plt.plot(distances, color='purple')
plt.title('K-Distance Graph untuk Menentukan Epsilon Optimal DBSCAN (5 Komponen PCA)')
plt.xlabel('Data Points tersortir')
plt.ylabel('Jarak Epsilon')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
# Berdasarkan K-Distance Graph pada data PCA 5D, letak 'elbow' (tekukan) berada di sekitar epsilon 0.5 - 0.8.
# Kita gunakan eps = 0.6 sebagai nilai eksperimen awal yang masuk akal.
eps_optimal = 0.6

dbscan_model = DBSCAN(eps=eps_optimal, min_samples=min_samples)
dbscan_labels = dbscan_model.fit_predict(X_pca_5)

# Menyimpan hasil prediksi DBSCAN ke dataframe PCA (untuk visualisasi 2D)
pca_df['DBSCAN_Cluster'] = dbscan_labels

print(f"Jumlah klaster DBSCAN (tidak termasuk noise -1): {len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)}")
print(f"Jumlah data noise (label -1): {list(dbscan_labels).count(-1)}")
# Out:
# Jumlah klaster DBSCAN (tidak termasuk noise -1): 11
# Jumlah data noise (label -1): 447

# %%
# Eksperimen Kedua: Melonggarkan Epsilon menjadi 0.8 pada data PCA 5D
eps_eksperimen = 0.8

dbscan_model_2 = DBSCAN(eps=eps_eksperimen, min_samples=min_samples)
dbscan_labels_2 = dbscan_model_2.fit_predict(X_pca_5)

print(f"--- HASIL EKSPERIMEN (EPS = 0.8) ---")
print(f"Jumlah klaster DBSCAN: {len(set(dbscan_labels_2)) - (1 if -1 in dbscan_labels_2 else 0)}")
print(f"Jumlah data noise (label -1): {list(dbscan_labels_2).count(-1)}")
print(f"Persentase noise: {(list(dbscan_labels_2).count(-1) / len(X_pca_5)) * 100:.2f}%")
# Out:
# --- HASIL EKSPERIMEN (EPS = 0.8) ---
# Jumlah klaster DBSCAN: 6
# Jumlah data noise (label -1): 106
# Persentase noise: 4.82%

# %% [markdown]
# ## 10. Evaluasi Model
# Membandingkan performa K-Means dan DBSCAN menggunakan tiga metrik utama:
# 1. **Silhouette Score**: Mendekati 1 lebih baik.
# 2. **Davies-Bouldin Index (DBI)**: Semakin rendah (mendekati 0) semakin baik.
# 3. **Adjusted Rand Index (ARI)**: Mendekati 1 berarti hasil klasterisasi semakin cocok dengan label asli.

# %%
# Evaluasi K-Means pada PCA 5D
km_silhouette = silhouette_score(X_pca_5, kmeans_labels)
km_dbi = davies_bouldin_score(X_pca_5, kmeans_labels)
km_ari = adjusted_rand_score(y_true, kmeans_labels)

# Evaluasi DBSCAN (Dengan Noise) pada PCA 5D
try:
    db_silhouette = silhouette_score(X_pca_5, dbscan_labels)
    db_dbi = davies_bouldin_score(X_pca_5, dbscan_labels)
except ValueError:
    db_silhouette = np.nan
    db_dbi = np.nan
    
db_ari = adjusted_rand_score(y_true, dbscan_labels)

# Evaluasi DBSCAN (Tanpa Noise/Hanya Klaster Valid) pada PCA 5D
dbscan_non_noise = dbscan_labels != -1
if dbscan_non_noise.sum() > 0 and len(set(dbscan_labels[dbscan_non_noise])) > 1:
    db_silhouette_clean = silhouette_score(X_pca_5[dbscan_non_noise], dbscan_labels[dbscan_non_noise])
    db_dbi_clean = davies_bouldin_score(X_pca_5[dbscan_non_noise], dbscan_labels[dbscan_non_noise])
    db_ari_clean = adjusted_rand_score(y_true[dbscan_non_noise], dbscan_labels[dbscan_non_noise])
else:
    db_silhouette_clean = np.nan
    db_dbi_clean = np.nan
    db_ari_clean = np.nan

evaluation_df = pd.DataFrame({
    'Metric': ['Silhouette Score', 'Davies-Bouldin Index', 'Adjusted Rand Index (ARI)'],
    'K-Means (K=22)': [km_silhouette, km_dbi, km_ari],
    'DBSCAN (Dengan Noise)': [db_silhouette, db_dbi, db_ari],
    'DBSCAN (Tanpa Noise)': [db_silhouette_clean, db_dbi_clean, db_ari_clean]
})

display(evaluation_df)
# Out:
#                       Metric  K-Means (K=22)  DBSCAN (Dengan Noise)  \
# 0           Silhouette Score        0.307365               0.057978
# 1       Davies-Bouldin Index        1.081402               1.609342
# 2  Adjusted Rand Index (ARI)        0.519379               0.219566
#
#    DBSCAN (Tanpa Noise)
# 0              0.181318
# 1              0.983638
# 2              0.219566

# %% [markdown]
# ## 11. Visualisasi Hasil Klasterisasi
# Menampilkan hasil klasterisasi dalam visualisasi 2D (menggunakan proyeksi 2 komponen PCA pertama) dan visualisasi 5D (menggunakan pairplot untuk 5 komponen utama PCA). Visualisasi 5D ini berguna untuk melihat secara langsung bagaimana kelompok terbentuk pada ruang fitur yang sebenarnya digunakan dalam proses modeling.

# %%
# 1. Visualisasi K-Means 2D (menggunakan proyeksi 2 komponen PCA pertama)
fig1, ax1 = plt.subplots(figsize=(8, 7))
sns.scatterplot(x='PC1', y='PC2', hue='KMeans_Cluster', data=pca_df, palette='tab20', ax=ax1, legend=False, alpha=0.7)
ax1.set_title('Hasil Klasterisasi K-Means (K=22) - Proyeksi 2D')
ax1.set_xlabel('Principal Component 1')
ax1.set_ylabel('Principal Component 2')
plt.tight_layout()
plt.show()

# 2. Visualisasi K-Means 5D (menggunakan 5 komponen PCA yang digunakan untuk modeling)
pca_5_df['KMeans_Cluster'] = kmeans_labels
sns.pairplot(pca_5_df.drop('label', axis=1), hue='KMeans_Cluster', palette='tab20', plot_kws={'alpha': 0.5}, corner=True)
plt.suptitle('Hasil Klasterisasi K-Means (K=22) - Pairplot 5D PCA', y=1.02, fontsize=16)
plt.show()

# %%
# 1. Visualisasi DBSCAN 2D (menggunakan proyeksi 2 komponen PCA pertama)
fig2, ax2 = plt.subplots(figsize=(9, 7)) # Sedikit lebih lebar untuk menampung legenda
sns.scatterplot(x='PC1', y='PC2', hue='DBSCAN_Cluster', data=pca_df, palette='Set1', ax=ax2, legend='full', alpha=0.7)
ax2.set_title('Hasil Klasterisasi DBSCAN - Proyeksi 2D')
ax2.set_xlabel('Principal Component 1')
ax2.set_ylabel('Principal Component 2')
plt.tight_layout()
plt.show()

# 2. Visualisasi DBSCAN 5D (menggunakan 5 komponen PCA yang digunakan untuk modeling)
pca_5_df['DBSCAN_Cluster'] = dbscan_labels
sns.pairplot(pca_5_df.drop(['label', 'KMeans_Cluster'], axis=1, errors='ignore'), hue='DBSCAN_Cluster', palette='Set1', plot_kws={'alpha': 0.5}, corner=True)
plt.suptitle('Hasil Klasterisasi DBSCAN - Pairplot 5D PCA', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# ## 12. Analisis dan Interpretasi Hasil
# Melihat karakteristik dari setiap klaster yang dibentuk oleh K-Means (sebagai model dengan performa ARI lebih baik). Nilai *mean* dari setiap fitur dapat menjelaskan kondisi lingkungan yang optimal untuk klaster tanaman tersebut.

# %%
# Menambahkan hasil K-Means ke dataframe asli
df['Cluster'] = kmeans_labels

# Menghitung nilai rata-rata tiap fitur numerik untuk setiap klaster
cluster_summary = df.groupby('Cluster')[numeric_cols].mean()
display(cluster_summary.head(10).style.background_gradient(cmap='Greens'))

# Contoh interpretasi beberapa klaster
print("\nAnalisis Tanaman pada Cluster 0:")
print(df[df['Cluster'] == 0]['label'].value_counts())

print("\nAnalisis Tanaman pada Cluster 1:")
print(df[df['Cluster'] == 1]['label'].value_counts())
# Out:
# <style type="text/css">
# #T_9a7b1_row0_col0 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_9a7b1_row0_col1, #T_9a7b1_row4_col3, #T_9a7b1_row4_col4, #T_9a7b1_row7_col2, #T_9a7b1_row7_col6, #T_9a7b1_row8_col0, #T_9a7b1_row9_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_9a7b1_row0_col2, #T_9a7b1_row8_col2 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_9a7b1_row0_col3 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_9a7b1_row0_col4, #T_9a7b1_row9_col4 {
#   background-color: #05712f;
#   color: #f1f1f1;
# }
# #T_9a7b1_row0_col5 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_9a7b1_row0_col6 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_9a7b1_row1_col0 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_9a7b1_row1_col1, #T_9a7b1_row1_col2, #T_9a7b1_row2_col0, #T_9a7b1_row3_col4, #T_9a7b1_row7_col5, #T_9a7b1_row8_col3, #T_9a7b1_row9_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_9a7b1_row1_col3 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_9a7b1_row1_col4 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_9a7b1_row1_col5, #T_9a7b1_row7_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_9a7b1_row1_col6 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_9a7b1_row2_col1, #T_9a7b1_row6_col3 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_9a7b1_row2_col2 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_9a7b1_row2_col3 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_9a7b1_row2_col4, #T_9a7b1_row3_col3 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_9a7b1_row2_col5 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_9a7b1_row2_col6 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_9a7b1_row3_col0, #T_9a7b1_row4_col5, #T_9a7b1_row6_col2 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_9a7b1_row3_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_9a7b1_row3_col2, #T_9a7b1_row3_col5 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_9a7b1_row3_col6 {
#   background-color: #339c52;
#   color: #f1f1f1;
# }
# #T_9a7b1_row4_col0 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_9a7b1_row4_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_9a7b1_row4_col2 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_9a7b1_row4_col6 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_9a7b1_row5_col0 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_9a7b1_row5_col1 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_9a7b1_row5_col2 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_9a7b1_row5_col3 {
#   background-color: #00471c;
#   color: #f1f1f1;
# }
# #T_9a7b1_row5_col4 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_9a7b1_row5_col5 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_9a7b1_row5_col6 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_9a7b1_row6_col0 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_9a7b1_row6_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_9a7b1_row6_col4 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_9a7b1_row6_col5 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_9a7b1_row6_col6 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_9a7b1_row7_col1 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_9a7b1_row7_col3 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_9a7b1_row7_col4 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_9a7b1_row8_col1 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_9a7b1_row8_col4 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_9a7b1_row8_col5 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_9a7b1_row8_col6 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_9a7b1_row9_col0 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_9a7b1_row9_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_9a7b1_row9_col2 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_9a7b1_row9_col3 {
#   background-color: #91d28e;
#   color: #000000;
# }
# </style>
# <table id="T_9a7b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a7b1_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_9a7b1_level0_col1" class="col_heading level0 col1" >P</th>
#       <th id="T_9a7b1_level0_col2" class="col_heading level0 col2" >K</th>
#       <th id="T_9a7b1_level0_col3" class="col_heading level0 col3" >temperature</th>
#       <th id="T_9a7b1_level0_col4" class="col_heading level0 col4" >humidity</th>
#       <th id="T_9a7b1_level0_col5" class="col_heading level0 col5" >ph</th>
#       <th id="T_9a7b1_level0_col6" class="col_heading level0 col6" >rainfall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a7b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a7b1_row0_col0" class="data row0 col0" >38.252174</td>
#       <td id="T_9a7b1_row0_col1" class="data row0 col1" >23.973913</td>
#       <td id="T_9a7b1_row0_col2" class="data row0 col2" >25.156522</td>
#       <td id="T_9a7b1_row0_col3" class="data row0 col3" >21.115924</td>
#       <td id="T_9a7b1_row0_col4" class="data row0 col4" >82.640455</td>
#       <td id="T_9a7b1_row0_col5" class="data row0 col5" >7.208303</td>
#       <td id="T_9a7b1_row0_col6" class="data row0 col6" >121.771956</td>
#     </tr>
#     <tr>
#       <th id="T_9a7b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a7b1_row1_col0" class="data row1 col0" >20.837398</td>
#       <td id="T_9a7b1_row1_col1" class="data row1 col1" >134.081301</td>
#       <td id="T_9a7b1_row1_col2" class="data row1 col2" >199.788618</td>
#       <td id="T_9a7b1_row1_col3" class="data row1 col3" >22.893690</td>
#       <td id="T_9a7b1_row1_col4" class="data row1 col4" >90.395344</td>
#       <td id="T_9a7b1_row1_col5" class="data row1 col5" >5.966841</td>
#       <td id="T_9a7b1_row1_col6" class="data row1 col6" >104.624560</td>
#     </tr>
#     <tr>
#       <th id="T_9a7b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9a7b1_row2_col0" class="data row2 col0" >98.311321</td>
#       <td id="T_9a7b1_row2_col1" class="data row2 col1" >81.009434</td>
#       <td id="T_9a7b1_row2_col2" class="data row2 col2" >50.113208</td>
#       <td id="T_9a7b1_row2_col3" class="data row2 col3" >27.323358</td>
#       <td id="T_9a7b1_row2_col4" class="data row2 col4" >81.084615</td>
#       <td id="T_9a7b1_row2_col5" class="data row2 col5" >6.025347</td>
#       <td id="T_9a7b1_row2_col6" class="data row2 col6" >102.715379</td>
#     </tr>
#     <tr>
#       <th id="T_9a7b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9a7b1_row3_col0" class="data row3 col0" >25.353982</td>
#       <td id="T_9a7b1_row3_col1" class="data row3 col1" >24.672566</td>
#       <td id="T_9a7b1_row3_col2" class="data row3 col2" >32.238938</td>
#       <td id="T_9a7b1_row3_col3" class="data row3 col3" >28.169459</td>
#       <td id="T_9a7b1_row3_col4" class="data row3 col4" >92.722677</td>
#       <td id="T_9a7b1_row3_col5" class="data row3 col5" >6.044238</td>
#       <td id="T_9a7b1_row3_col6" class="data row3 col6" >183.465093</td>
#     </tr>
#     <tr>
#       <th id="T_9a7b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9a7b1_row4_col0" class="data row4 col0" >29.102564</td>
#       <td id="T_9a7b1_row4_col1" class="data row4 col1" >68.897436</td>
#       <td id="T_9a7b1_row4_col2" class="data row4 col2" >47.435897</td>
#       <td id="T_9a7b1_row4_col3" class="data row4 col3" >19.172093</td>
#       <td id="T_9a7b1_row4_col4" class="data row4 col4" >21.655064</td>
#       <td id="T_9a7b1_row4_col5" class="data row4 col5" >6.091366</td>
#       <td id="T_9a7b1_row4_col6" class="data row4 col6" >78.613143</td>
#     </tr>
#     <tr>
#       <th id="T_9a7b1_level0_row5" clas
# Analisis Tanaman pada Cluster 0:
# label
# orange         48
# pomegranate    30
# coffee         20
# jute           13
# pigeonpeas      3
# maize           1
# Name: count, dtype: int64
#
# Analisis Tanaman pada Cluster 1:
# label
# apple     100
# grapes     23
# Name: count, dtype: int64

# %% [markdown]
# ## 13. Kesimpulan dan Saran
#
# ### Kesimpulan
# 1. **Penyelesaian Permasalahan Rekomendasi Tanaman Multilabel**: Pendekatan klasterisasi terbukti menjadi solusi alternatif yang unggul untuk menghasilkan rekomendasi tanaman multilabel dari dataset bertipe *single-label*. Dengan mengelompokkan lahan yang memiliki kemiripan hara dan iklim, model dapat mengidentifikasi rumpun komoditas potensial secara berkelompok.
# 2. **K-Means vs DBSCAN (PCA 5D)**: K-Means jauh lebih unggul dengan Adjusted Rand Index (ARI) sebesar ~0.52 dibandingkan DBSCAN (eps=0.6, min_samples=14) yang bernilai ~0.29. Hal ini dikarenakan struktur spasial data agronomi cenderung tersebar secara radial di sekitar pusat (*centroid*) komoditas, sementara DBSCAN kesulitan membedakan perbatasan komoditas yang saling tumpang tindih (*overlapping*), sehingga melabeli 636 data (28.91%) sebagai noise.
# 3. **Pentingnya Standardisasi & Outlier Preservation**: Standardisasi menggunakan `StandardScaler` krusial bagi kedua algoritma berbasis jarak ini. Outlier agronomi yang terdeteksi lewat Boxplot sengaja dipertahankan karena merepresentasikan kondisi ekologis alami yang sah dari komoditas bernilai tinggi (misalnya kalium ekstrim pada anggur/apel), sehingga jika dihapus akan merusak taksonomi rekomendasi.
#
# ### Saran
# 1. **Eksplorasi Soft/Probabilistic Clustering**: Untuk mengatasi batas antar-lahan yang kontinu dan rigiditas K-Means, disarankan mencoba model klasterisasi lunak seperti *Gaussian Mixture Model (GMM)* atau *Fuzzy C-Means (FCM)* untuk memberikan multilabel berperingkat berdasarkan derajat keanggotaan.
# 2. **Ekspor Model & Pipeline PCA**: Model K-Means (`kmeans_model.joblib`), Scaler (`scaler.joblib`), dan reduksi PCA (`pca_5.joblib`) harus disimpan bersama untuk memastikan integritas input data saat proses inferensi dideploy pada aplikasi web Streamlit.

# %%
import joblib

# Menyimpan model K-Means, Scaler, dan PCA 5
joblib.dump(kmeans_model, 'kmeans_model.joblib')
joblib.dump(scaler, 'scaler.joblib')
joblib.dump(pca_5, 'pca_5.joblib')

print("Model K-Means, Scaler, dan PCA 5D berhasil disimpan!")
# Out:
# Model K-Means, Scaler, dan PCA 5D berhasil disimpan!
